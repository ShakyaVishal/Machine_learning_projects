# %% [markdown]
# Importing Library For Connecting Sql With Python

# %%
import mysql.connector

# %% [markdown]
# Connecting Database

# %%
mydbMarks=mysql.connector.connect(host='localhost',user='root',password='UMESHumesh@321',db='student_marks')

# %%
import pandas as pd

# %%
Marks=pd.read_sql_query("select * from marks",mydbMarks)

# %%
Marks.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %% [markdown]
# Exploring Data(EDA)

# %%
Marks.shape
# Out:
# (10, 11)

# %%
Marks.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civics'],
#       dtype='object')

# %%
Marks.dtypes
# Out:
# Name         object
# Gender       object
# DOB          object
# Maths         int64
# Physics       int64
# Chemistry     int64
# English       int64
# Biology       int64
# Economics     int64
# History       int64
# Civics        int64
# dtype: object

# %%
Marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
# Name         10 non-null object
# Gender       10 non-null object
# DOB          10 non-null object
# Maths        10 non-null int64
# Physics      10 non-null int64
# Chemistry    10 non-null int64
# English      10 non-null int64
# Biology      10 non-null int64
# Economics    10 non-null int64
# History      10 non-null int64
# Civics       10 non-null int64
# dtypes: int64(8), object(3)
# memory usage: 960.0+ bytes

# %%
Marks.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %% [markdown]
# Importing Library for Visulizing data

# %%
import seaborn as sns

# %%
sns.heatmap(Marks.isnull())

# %%
sns.heatmap(Marks.corr(),annot=True)

# %% [markdown]
# Distribution of Maths marks

# %%
Marks['Maths'].plot.hist()

# %%
Marks['Maths'].plot.box()

# %% [markdown]
# Male are slightly good in maths as compared to Female

# %%
sns.barplot(x="Gender",y="Maths",data=Marks)

# %% [markdown]
# Distribution of Physics marks

# %%
Marks['Physics'].plot.hist()

# %%
Marks['Physics'].plot.box()

# %% [markdown]
# Female are good in physics as compared to Male

# %%
sns.barplot(x="Gender",y="Physics",data=Marks)

# %% [markdown]
# Distribution of Chemistry marks

# %%
Marks["Chemistry"].plot.hist()

# %%
Marks["Chemistry"].plot.box()

# %% [markdown]
# Male are slightly good in Chemistry as compared to Female

# %%
sns.barplot(x="Gender",y="Chemistry",data=Marks)

# %% [markdown]
# Distribution of English marks

# %%
Marks['English'].plot.hist()

# %%
Marks['English'].plot.box()

# %% [markdown]
# Male are good in English as compared to Female

# %%
sns.barplot(x="Gender",y="English",data=Marks)

# %% [markdown]
# Distribution of Biology marks

# %%
Marks['Biology'].plot.hist()

# %%
Marks['Biology'].plot.box()

# %% [markdown]
# Female are good in Biology as compared to Male

# %%
sns.barplot(x="Gender",y="Biology",data=Marks)

# %% [markdown]
# Distribution of Economics marks

# %%
Marks['Economics'].plot.hist()

# %%
Marks['Economics'].plot.box()

# %% [markdown]
# Female are good in Economics as compared to Male

# %%
sns.barplot(x="Gender",y="Economics",data=Marks)

# %% [markdown]
# Distribution of History marks

# %%
Marks['History'].plot.hist()

# %%
Marks['History'].plot.box()

# %% [markdown]
# Female are good in History as compared to Male

# %%
sns.barplot(x="Gender",y="History",data=Marks)

# %% [markdown]
# Distribution of Civics marks

# %%
Marks['Civics'].plot.hist()

# %%
Marks['Civics'].plot.box()

# %% [markdown]
# Male and Female both are good in Civics

# %%
sns.barplot(x="Gender",y="Civics",data=Marks)

# %%
sns.pairplot(Marks,hue="Gender")
