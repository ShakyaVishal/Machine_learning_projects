# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('hour.csv')

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %%
df.shape
# Out:
# (17379, 17)

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
# instant       17379 non-null int64
# dteday        17379 non-null object
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# casual        17379 non-null int64
# registered    17379 non-null int64
# cnt           17379 non-null int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
df.drop(['instant'],axis=1,inplace=True)
df.drop(['dteday'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (17379, 15)

# %%
df.describe()
# Out:
#              season            yr          mnth            hr       holiday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775     11.546752      0.028770
# std        1.106918      0.500008      3.438776      6.914405      0.167165
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%        2.000000      0.000000      4.000000      6.000000      0.000000
# 50%        3.000000      1.000000      7.000000     12.000000      0.000000
# 75%        3.000000      1.000000     10.000000     18.000000      0.000000
# max        4.000000      1.000000     12.000000     23.000000      1.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       3.003683      0.682721      1.425283      0.496987      0.475775
# ...

# %%
plt.figure(figsize=(20,30))
sns.heatmap(df.corr(),annot=True,cmap="RdBu_r")

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E600AF2E8>,
# ...
#       dtype=object)

# %%
df.skew()
# Out:
# season       -0.005416
# yr           -0.010243
# mnth         -0.009253
# hr           -0.010680
# holiday       5.638538
# weekday      -0.002998
# workingday   -0.785258
# weathersit    1.228047
# temp         -0.006021
# atemp        -0.090429
# hum          -0.111287
# windspeed     0.574905
# casual        2.499237
# registered    1.557904
# cnt           1.277412
# dtype: float64

# %%
for i in df:
    plt.figure(figsize=(10,30))
    plt.subplot(311)
    sns.distplot(df[i])
    plt.subplot(312)
    sns.boxplot(df[i],orient='v')

# %%
sns.countplot(df['season'])

# %%
sns.catplot(x='season',y='cnt',data=df,kind='bar')

# %%
sns.countplot(df['mnth'])

# %%
sns.catplot(x='mnth',y='cnt',data=df,kind='bar')

# %%
sns.countplot(df['weekday'])

# %%
sns.catplot(x='weekday',y='cnt',data=df,kind='bar')

# %%
sns.countplot(df['yr'])

# %%
sns.catplot(x='yr',y='cnt',data=df,kind='bar')

# %%
sns.catplot(x='holiday',y='cnt',data=df,kind='bar')

# %%
sns.catplot(x='workingday',y='cnt',data=df,kind='bar')

# %%
sns.catplot(x='weathersit',y='cnt',data=df,kind='bar')

# %%
sns.catplot(x='holiday',y='cnt',hue='season',data=df,kind='bar')

# %%
sns.catplot(x='workingday',y='cnt',hue='season',data=df,kind='bar')

# %%
sns.relplot(x='temp',y='windspeed',hue='cnt',data=df)

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,30))
sns.pairplot(x_vars=['temp','atemp','hum','windspeed'],y_vars='cnt',data=df,kind='reg')

# %%
from scipy import stats
newdf=df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]

# %%
newdf.shape
# Out:
# (15934, 15)

# %%
df.shape
# Out:
# (17379, 15)

# %%
x=df.iloc[:,:-1]
x.head()
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0       1   0     1   0        0        6           0           1  0.24
# 1       1   0     1   1        0        6           0           1  0.22
# 2       1   0     1   2        0        6           0           1  0.22
# 3       1   0     1   3        0        6           0           1  0.24
# 4       1   0     1   4        0        6           0           1  0.24
#
#     atemp   hum  windspeed  casual  registered
# 0  0.2879  0.81        0.0       3          13
# 1  0.2727  0.80        0.0       8          32
# 2  0.2727  0.80        0.0       5          27
# 3  0.2879  0.75        0.0       3          10
# 4  0.2879  0.75        0.0       0           1

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
y=df.iloc[:,-1]
y.head()
# Out:
# 0    16
# 1    40
# 2    32
# 3    13
# 4     1
# Name: cnt, dtype: int64

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=56)

# %%
print(x_train.shape,y_train.shape)
# Out:
# (11643, 14) (11643,)

# %%
print(x_test.shape,y_test.shape)
# Out:
# (5736, 14) (5736,)

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet,LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor

# %%
LR=LinearRegression()
LA=Lasso()
RI=Ridge()
EN=ElasticNet()
DTR=DecisionTreeRegressor(random_state=23)
KNR=KNeighborsRegressor()
ABR=AdaBoostRegressor(random_state=23)
RFR=RandomForestRegressor(random_state=23)
GBR=GradientBoostingRegressor(random_state=23)

# %%
models=[]
models.append(('LinearRegression',LR))
models.append(('Lasso',LA))
models.append(('Ridge',RI))
models.append(('ElasticNet',EN))
models.append(('DecisionTreeRegressor',DTR))
models.append(('KNeighborsRegressor',KNR))
models.append(('AdaBoostRegressor',ABR))
models.append(('RandomForestRegressor',RFR))
models.append(('GradientBoostingRegressor',GBR))

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
Model=[]
R2_score=[]
cvs=[]
MSE=[]
for name,model in models:
    print('*********************************',name,'*********************************')
    print('\n',model)
    Model.append(name)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    r2=r2_score(y_test,pre)
    print('R2_score = ',r2)
    R2_score.append(r2)
    mse=mean_squared_error(y_test,pre)
    print("Mean_Squared_Error =",mse)
    MSE.append(round(mse,3))
    score= cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score = ',score)
    cvs.append(round(score,3))
    print('\n')
# Out:
# ********************************* LinearRegression *********************************
#
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
# R2_score =  1.0
# Mean_Squared_Error = 3.701633748158209e-26
# Cross_Val_Score =  1.0
#
#
# ********************************* Lasso *********************************
#
#  Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)
# R2_score =  0.9999599820996884
# Mean_Squared_Error = 1.324314388309043
# Cross_Val_Score =  0.9999365181760934
#
#
# ********************************* Ridge *********************************
#
#  Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
# R2_score =  0.9999999921670721
# Mean_Squared_Error = 0.00025921547676041444
# ...

# %%
result = pd.DataFrame({'Model': Model, 'R2_score': R2_score ,'Mean_Squared_Error' :MSE,'Cross_val_score':cvs})
result
# Out:
#                        Model  R2_score  Mean_Squared_Error  Cross_val_score
# 0           LinearRegression  1.000000               0.000            1.000
# 1                      Lasso  0.999960               1.324            1.000
# 2                      Ridge  1.000000               0.000            1.000
# 3                 ElasticNet  0.918975            2681.367            0.898
# 4      DecisionTreeRegressor  0.999067              30.882            0.999
# 5        KNeighborsRegressor  0.961331            1279.673            0.905
# 6          AdaBoostRegressor  0.978054             726.271            0.955
# 7      RandomForestRegressor  0.999457              17.954            1.000
# 8  GradientBoostingRegressor  0.999185              26.972            0.999

# %% [markdown]
# **LinearRegression and Regularization technique(Ridge,Lasso) are working verygood on our dataset but I choose Ridge as my final model because it has less Mean_Squared_Error as compared to LinearRegression**

# %%
from sklearn.externals import joblib
joblib.dump(RI,'model_BikeSharing.csv')
# Out:
# ['model_BikeSharing.csv']

# %%
model=joblib.load('model_BikeSharing.csv')

# %%
model.predict(x_test)
# Out:
# array([  6.00007751, 171.01216089, 333.97397557, ...,  10.00692313,
#        321.00829776, 137.00056116])
